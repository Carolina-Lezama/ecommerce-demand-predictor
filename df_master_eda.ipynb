# %%
# Configurar el estilo visual (para que se vea más profesional)
sns.set_theme(style="whitegrid")

# Crear el lienzo usando Matplotlib
plt.figure(figsize=(10, 5))

# Dibujar el gráfico usando Seaborn (ejemplo: contar cuántos pedidos hay por estado)
sns.countplot(data=df_orders, x='order_status', palette='viridis')

# Añadir títulos y detalles
plt.title('Distribución del Estado de los Pedidos', fontsize=14)
plt.xlabel('Estado del Pedido')
plt.ylabel('Cantidad de Pedidos')

# Mostrar el gráfico
plt.show()

# %%
#IMPORTACION DE LIBERIAS

# Manejo de datos
import numpy as np
import pandas as pd

# Visualizacion
import matplotlib.pyplot as plt
import seaborn as sns

from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

# MÉTRICAS DE CLASIFICACIÓN
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# DIVISIÓN 
from sklearn.model_selection import train_test_split

# PREPROCESAMIENTO
from sklearn.preprocessing import StandardScaler, OneHotEncoder
# MODELOS DE CLASIFICACIÓN

# 1. Regresión Logística (baseline)
from sklearn.linear_model import LogisticRegression

# 2. Bosque Aleatorio
from sklearn.ensemble import RandomForestClassifier

# 3. Gradient Boosting (sklearn)
from sklearn.ensemble import GradientBoostingClassifier

# 4. LightGBM
from lightgbm import LGBMClassifier

# 5. XGBoost
from xgboost import XGBClassifier

# 6. CatBoost
from catboost import CatBoostClassifier

# %%
# Cargar las credenciales del archivo .env
load_dotenv()

USER = os.getenv('POSTGRES_USER')
PASSWORD = os.getenv('POSTGRES_PASSWORD')
HOST = os.getenv('POSTGRES_HOST')
PORT = os.getenv('POSTGRES_PORT') 
DB = os.getenv('POSTGRES_DB')

# 2. Crear la conexión a PostgreSQL
engine = create_engine(f'postgresql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB}')

print("Conexión a la base de datos establecida")

# %%
SELECT 
    o.order_purchase_timestamp, -- Para saber la fecha de la demanda
    i.product_id,               -- Para saber qué producto fue
    i.price,                    -- Para tu optimización de precios
    p.product_category_name     -- Para agrupar por categoría
FROM olist_orders_dataset o
JOIN olist_order_items_dataset i 
    ON o.order_id = i.order_id
JOIN olist_products_dataset p 
    ON i.product_id = p.product_id
WHERE o.order_status = 'delivered'; -- Tu filtro de limpieza

# ORDER ITEMS
query = """
SELECT * FROM olist_order_items_dataset
"""
df_order_items = pd.read_sql(query, engine)
