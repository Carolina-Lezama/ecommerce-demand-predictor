# %%
#IMPORTACION DE LIBERIAS

# Manejo de datos
import numpy as np
import pandas as pd
from IPython.display import display

from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

# %%
# Cargar las credenciales del archivo .env
load_dotenv()

USER = os.getenv('POSTGRES_USER')
PASSWORD = os.getenv('POSTGRES_PASSWORD')
HOST = os.getenv('POSTGRES_HOST')
PORT = os.getenv('POSTGRES_PORT') 
DB = os.getenv('POSTGRES_DB')

# 2. Crear la conexión a PostgreSQL
engine = create_engine(f'postgresql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB}')

print("Conexión a la base de datos establecida")
# Out:
# Conexión a la base de datos establecida

# %%
# ORDERS
# 1. Definir la consulta SQL
query = """
SELECT * FROM olist_orders_dataset 
"""

# 2. Ejecutar la consulta y guardarla
df_orders = pd.read_sql(query, engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\michi\OneDrive\Desktop\ecommerce-demand-predictor\venv\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\michi\OneDrive\Desktop\ecommerce-demand-predictor\venv\Lib\site-packages\sqlalchemy\engine\base.py:3304, in Engine.raw_connection(self)
#    3283 """Return a "raw" DBAPI connection from the connection pool.
#    3284
#    3285 The returned object is a proxied version of the DBAPI
#    (...)   3302
#    3303 """
# -> 3304 return self.pool.connect()
#
# ...

# %%
# ORDER ITEMS
query = """
SELECT * FROM olist_order_items_dataset
"""
df_order_items = pd.read_sql(query, engine)

# %%
# PRODUCTS
query = """
SELECT * FROM olist_products_dataset
"""
df_products = pd.read_sql(query, engine)

# %%
# Funcion de analisis exploratorio base
def exploracion_profesional(df):
    print(" ANÁLISIS EXPLORATORIO BASE\n")
    print("Informacion general: ")
    
    df.info()
    
    print()
    print(f"Filas duplicadas totales: {df.duplicated().sum()}\n")
    
    print("Primeras 5 filas:")
    print(df.head())
    print()
    
    print("Descripción Estadística (Variables Numéricas): ")
    print(df.describe().round(2))
    print()
    
    print("Resumen de Nulos y Valores Únicos por Columna:")
    
    resumen = pd.DataFrame({
        'Tipo de Dato': df.dtypes,
        'Valores Nulos': df.isnull().sum(),
        '% Nulos': (df.isnull().sum() / len(df) * 100).round(2),
        'Valores Únicos': df.nunique()
    })
    
    display(resumen)
    
    print("\n Frecuencia de categorías (Solo columnas con menos de 40 valores únicos):")
    
    for column in df.columns:
        
        print(f"Total de valores unicos: {df[column].nunique()} ")
        
        if df[column].nunique() < 40:
            print(f"\n- Columna: '{column}'")
            print(df[column].value_counts())

# %%
exploracion_profesional(df_orders)
# Out:
#  ANÁLISIS EXPLORATORIO BASE
#
# Informacion general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
#
# Filas duplicadas totales: 0
#
# Primeras 5 filas:
#                            order_id                       customer_id  \
# ...

# %% [markdown]
# # Observaciones olist_orders_dataset:
# - Todas las columnas son de tipo object / Columnas con posible cambio a datetime para aplicar data engineering (temporalidad)
# - order_status tiene 8 posibles valores diferentes, delivered es casi la mayoria absoluta, observar a fondo los casos anomalos
# - order_estimated_delivery_date a diferencia de otras columnas de tiempo, tiene menos de 500 valores unicos, revisar correlacion del porque hay una fecha de coincidencia
# - Antes de entrenar es necesario quitar filas que puedan introducir el data leakage
# - Los nulos no son errores del sistema; están vacíos simplemente porque esos pedidos nunca llegaron al cliente.

# %%
exploracion_profesional(df_order_items)
# Out:
#  ANÁLISIS EXPLORATORIO BASE
#
# Informacion general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
#
# Filas duplicadas totales: 0
#
# Primeras 5 filas:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# ...

# %% [markdown]
# # Observaciones olist_order_items_dataset:
# - No hay presencia de nulos en ninguna columna, verificar datos incorrectos
# - es posible convertir shipping_limit_date a datatime y extrare feautes para entrenar un modelo de temporalidad
# - order_item_id no es un código de categoría ni un identificador de producto. Es un contador secuencial dentro del pedido. El primer artículo del carrito recibe el 1, el segundo el 2, el tercero el 3, la inmensa mayoría de los clientes solo llevan 1 artículo (por eso el P75 es 1).
# - El precio mínimo es 0.85 (no hay precios en cero ni negativos, lo cual es excelente)
# - freight_value parece tener outliers, mucha desproporcion de valores en percentiles
# - order_id parece ser repetida, aunque se supone que cada uno es una compra unica
# - esta tabla es el desglose del carrito de compras. Si un cliente compró 4 llantas en un solo pedido, aquí verás ese mismo order_id repetido 4 veces
# - El valor de envío (freight_value) mínimo es 0.00. Esto indica que existen campañas de envío gratis

# %%
exploracion_profesional(df_products)
# Out:
#  ANÁLISIS EXPLORATORIO BASE
#
# Informacion general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
#
# Filas duplicadas totales: 0
#
# Primeras 5 filas:
#                          product_id  product_category_name  \
# ...

# %% [markdown]
# # Observaciones olist_products_dataset:
# - Nunca verás el texto real de la descripción. En su lugar, se extrajo el conteo de caracteres del texto original y te lo entregaron como la variable numérica
# - presencia de nulos en la mayoria de columnas(Id es la excepcion). 1.85% de nulos en varias columnas. Esto indica que hay 610 productos huérfanos que el vendedor dio de alta en la plataforma sin asignarle categoría ni fotos, estos 610 registros sin categoría no nos sirven. Se deben filtrar con un WHERE product_category_name IS NOT NULL al momento de armar el dataset maestro en SQL.
# - product_weight_g  no puede tener productos con 0g de peso. Físicamente es imposible enviar un paquete que pese cero gramos. Es un error claro de captura en el sistema de inventario.
# - excluir todo el bloque volumétrico de nuestras features iniciales.
